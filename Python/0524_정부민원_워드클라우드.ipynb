# %%
import pandas as pd

# %%
from matplotlib.ticker import FuncFormatter
from matplotlib.colors import Normalize
import matplotlib.pyplot as plt
plt.rc('font',family='Malgun Gothic')

# %%
from wordcloud import WordCloud
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from wordcloud import WordCloud, STOPWORDS
from PIL import Image # 그림을 불러오는 패키지
import numpy as np
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Kipioneer\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kipioneer\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
with open("./해커톤/정부민원.txt", 'r', encoding='utf-8') as f:
    text = f.read()

# %%
text
# Out:
# '국세청 홈택스에서 종합소득세 신고 후 개인지방소득세(종합소득분) 연계 신고 방법은 어떻게 되나요?\n국세청 홈택스에서 양도소득세 신고 후 개인지방소득세(양도소득분) 연계 신고 방법은 어떻게 되나요?\n위택스에서 종합소득분 신고 취소 경로 알려주세요.\n위택스에서 종합소득분 신고 시 환급 계좌 입력은 필수인가요?\n종합소득분을 신고(납부)하였으나, 추가 납부할 세액이 발생한 경우 어떻게 해야 하나요?\n종합소득분을 과다 납부한 경우 어떻게 해야 하나요?\n홈택스에서 종합소득세(국세)를 환급으로 신고 후 종합소득분(지방세) 연계 신고하였으나, 납부할 세액이 확인됩니다.\n동물학대에는 어떤 종류가 있나요?\n반려동물 분실신고는 어떻게 하나요?\n반려동물 장례 절차가 있나요?\n반려동물을 분양을 받고자 하는데, 절차가 어떻게 되나요?\n로드킬 발견 시 신고는 어떻게 하나요?\n과수고품질시설 현대화 사업에 대해 궁금합니다.\n과수고품질시설현대화 사업 지원자격 및 지원내용, 신청방법 등이 궁금합니다.\n과수분야 스마트팜 확산사업에 대해 궁금합니다.\n유통시설현대화 사업에 대해 궁금합니다.\n과실브랜드 육성사업에 대해 궁금합니다.\n농지보전부담금은 무엇인가요?\n농지보전부담금 납부 관련 문의처를 알 수 있나요?\n농지보전부담금 납입확인서는 어떻게 발급 받을 수 있나요?\n농지법상 농지에 해당하지 않는 경우가 있나요?\n생애최초 부동산 취득 후 취득세 소급 및 환급 대상자입니다. 위택스에서 신청 가능한가요?\n청탁금지에 대해 궁금합니다.\n청탁금지법 부정청탁금지 위반사례가 궁금합니다.\n이해충돌 방지 세부행위기준에 대해 알고 싶습니다.\n이해충돌방지법이 무엇인가요?\n청탁금지법 금품 및 외부강의 등 초과사례금 수수사례가 궁금합니다.\n면제확인이란 무엇인가요?\n어린이보호포장이란 무엇인가요?\n수입통관신고란 무엇인가요?\n수입물품가격신고제도란 무엇인가요?\n잠정가격신고제도란 무엇인가요?\n다른 지역으로 이사한 경우 지방세 자동납부를 다시 신청해야 하나요?\n농로, 구거, 제방 등 개별공시지가가 없는 농지의 경우 농지보전부담금 부과 기준은 어떻게 되나요?\n농지보전부담금을 분할하여 납부할 수 있나요?\n농지를 산림(임야)로 전용하는 경우 농지보전부담금을 감면 받을 수 있나요?\n농지보전부담금을 납부한 후 사업을 포기할 경우 환급절차는 어떻게 되나요?\n행정심판 청구 후 청구내용을 수정할 수 있나요?\n행정심판 청구하는 방법을 청구인과 대리인 기준으로 상세하고 알고 싶습니다.\n처분받은 내용이 있는데 행정심판 접수대상이 되나요?\n제가 받은 처분이 특별행정심판위원회 소관인데 중앙행정심판위원회에도 함께 접수 할 수 있나요?\n서면으로 행정심판 접수 후 증거서류를 추가제출하거나 주소 등을 서면으로 변경할 수 있나요?\n행정심판 청구한 날로부터 60일(재결기간)이 지났는데 아직도 재결결과가 나오지 않았어요.\n행정심판 재결결과가 나오기까지 과정이 궁금합니다.\n중앙행정심판위원회의 재결결과에 이의가 있을 경우 행정소송이 가능한가요?\n행정심판 청구할 때 국선대리인을 선임하고자 합니다. 어떻게 해야 하나요?\n행정심판 청구 후 처분청의 답변서 제출기간, 심리기일 개최일, 재결서 발송일자 등을 알고 싶습니다.\n공익직불금을 신청하려고 하는데 어떻게 해야 하나요?\n행정심판 청구서 작성 시 업종, 사건유형, 처분구분 및 사건 사례별 청구서 조회방법 등 홈페이지에서 볼 수 있나요?\n내고장알리미 서비스란 무엇인가요?\n부모급여란 무엇인가요?\n타인 명의 차량의 자동차세를 연납 신청 할 수 있나요?\n환경개선부담금 연납신청 가능한가요?\n축산물 등급판정 확인서를 온라인을 발급 할 수 있나요?\n위택스에서 자동차세 연납신청은 어떻게 해야 하나요?\n2023년도에 자동차세 연납 공제율이 변경되었나요?\n지방세 납부 시 가상계좌 이외 납부방법이 있나요?\n위택스에서 취득세 공동명의 건에 대해서 신고필증 일련번호(관리번호) 입력 시 오류가 발생합니다.\n위택스에서 취득세 신고 시 비적정 메시지가 확인되며 신고가 안됩니다.\n증여, 기부 등 무상취득한 취득세(주택) 신고는 전자신고 가능한가요?\n심폐소생술 교육을 받을 수 있는 곳은 어디인가요?\n여권사실증명 온라인으로 발급 가능한가요?\n전자소송시스템을 통해 제출 가능한 서류는 어떤 종류가 있나요?\n수산질병관리사란 무엇인가요?\n스킨스쿠버를 하려는데, 바다의 상황을 미리 알 수 있는 방법이 있나요?\n축산물 잔류물질 검사 절차를 알고 싶어요.\n동물용 의약품을 안전하게 사용하는 방법 및 기준이 무엇인가요?\n축산물 잔류물질을 검사하는 기관은 어디인가요?\n동물용 의약품에는 어떤 종류가 있나요?\n축산물 허용물질목록 관리제도(PLS)가 무엇인가요?\n산지연금형 사유림매수 제도 참여 방법을 알고 싶어요.\n신용카드를 해지(분실)한 경우 위택스에서 지방세 자동납부 신청건은 어떻게 해지해야 하나요?\n임대사업자 부기등기 하는데 등록면허세(등록분) 영수필확인서가 필요합니다.\n위택스에서 임대사업자 부기등기 등록분 신고 시 상호명을 어떻게 입력해야 하나요?\n부기등기를 위해 등록면허세(등록분) 신고중인데 물건이 여러 개인 경우 한 번에 신고 가능한가요?\n직장 내 괴롭힘에 대한 상담을 받고 싶어요.\n소상공인 및 자영업자를 지원하는 사업이 어떤 것이 있는지 궁금합니다.\n생활불편신고 앱은 더 이상 이용할 수 없나요?\n스마트폰을 이용한 생활 속 불편 사항 신고방법을 알고 싶어요\n1회용 컵 보증금제란 무엇인가요?\n건설현장에 소방안전관리자 선임을 의무화 한다는데, 기준이 궁금해요.\n택시 야간 호출 제도가 궁금해요.\n수상레저기구 조종면허 갱신 교육은 어디서 받을 수 있나요?\n출석인정제도란 무엇인가요?\n한국어능력시험을 한국인도 볼 수 있나요?\n한국어능력시험 접수 시 입력한 응시자 정보 변경할 수 있나요?\n한국어능력시험 접수 후 응시료 결제 및 환불 관련해서 궁금해요\n한국어능력시험 성적증명서의 유효기간이 얼마나 되나요?\n한국어능력시험 접수 시 사진을 등록하고자 하는데 사진 규격이 어떻게 되나요?\n여성어업인인데 건강검진 지원받을 수 있나요?\n본인부담 초과 의료비 환급해준다던데, 대상확인 가능한가요?\n중고차를 샀는데, 침수 사실을 뒤늦게 알았어요. 신고 가능한가요?\n22년 11월부터 카페에서 일회용품 사용이 제한된다는데, 카페만 그런건가요?\n에코뱅크란 무엇인가요?\n무인민원발급기 위치를 알 수 있는 방법이 있나요?\n원양어선 등 한국선박에서 근무하는 외국인선원에 대해 상담할 수 있는 곳이 있나요?\n국유재산 불법으로 사용하고 있는 것을 신고하고자 하는데 어떻게 해야 하나요?\n국유부동산의 소관기관이나 관리기관을 알고 싶어요.\n국립종자원에 새로운 식물의 대한 품종등록출원을 하고 싶은데 어떻게 해야 할까요?\n국민참여플랫폼 ‘온(ON)국민소통’이 무엇인가요?\n친환경 보일러 보조금 온라인으로 신청 가능한가요?\n문화유산도서를 무료로 신청 가능한가요?\n지방소득세 양도소득분 과세표준은 어떤 금액을 입력하나요?\n지방세 고지서를 스마트폰으로 받을 수 있나요?\n주민등록증 모바일 확인 서비스란 무엇인가요?\n형사사법포털에서 공인증서와 지문인증을 제외한 다른 인증으로 이용할 수 있는 방법이 있나요?\n두낫콜 서비스란 무엇인가요?\n주민등록증 신규 발급(만 17세 이상 최초 발급) 전국 어디서나 가능한가요?\n적극행정 적립[마일리지] 제도란 무엇인가요?\n사업을 휴업하거나 폐업을 해야 하는 경우에 사업자등록은 어떻게 해야 하나요?\n사업자등록번호 부여체계에 대해 궁금합니다.\n사업자등록을 하려고 하는데 일반과세자와 간이과세자의 차이가 무엇인가요?\n사업자등록을 하지 않거나 다른 사람의 이름으로 하면 불이익이 있나요?\n개인사업을 하려고 하는데 사업자등록은 언제 어떻게 해야 하나요?\n지방세입계좌 납부서비스란 무엇인가요?\n재산세 분할납부 신청 시 본세, 지역자원시설세, 지방교육세 모두 분할된 세액으로 납부 가능한가요?\n지방세 자동납부는 자치단체별(행정구별)로 신청해야 하나요?\n양도소득분 신고 시 납세지 기준을 알려주세요.\n공동인증서와 금융인증서 차이가 뭔가요?\n아포스티유 확인이란?\n영사콜센터란?\n가족관계증명서 ...

# %%
from konlpy.tag import Okt, Kkma, Komoran

# %%
# pip install konlpy

# %%
# pip install JPype1-0.5.7-cp27-none-win_amd64.whl

# %%
okt = Okt()

# %%
tokens = okt.nouns(text)

# %%
tokens
# Out:
# ['국세청',
#  '홈택스',
#  '종합소득세',
#  '신고',
#  '후',
#  '개인',
#  '지방',
#  '소득세',
#  '종합',
#  '소득',
#  '계',
#  '신고',
#  '방법',
#  '국세청',
#  '홈택스',
#  '양도소득세',
#  '신고',
#  '후',
#  '개인',
#  '지방',
#  '소득세',
#  '양도소득',
#  '계',
#  '신고',
#  '방법',
#  '위택스',
#  '종합',
#  '소득',
#  '신고',
#  '취소',
#  '경로',
#  '위택스',
#  '종합',
#  '소득',
#  '신고',
#  '시',
#  '환급',
#  '계좌',
#  '입력',
#  '필수',
#  '종합',
#  '소득',
#  '신고',
#  '납부',
#  '추가',
#  '납부',
#  '세액',
#  '발생',
#  '경우',
#  '하나요',
#  '종합',
#  '소득',
#  '과',
#  '납부',
#  '경우',
#  '하나요',
#  '홈택스',
#  '종합소득세',
#  '국세',
#  '를',
#  '환급',
#  '신고',
#  '후',
#  '종합',
#  '소득',
#  '지방세',
#  '계',
#  '신고',
#  '납부',
#  '세액',
#  '확인',
#  '동물학대',
#  '종류',
#  '반려동물',
#  '분실',
#  '신고',
#  '하나요',
#  '반려동물',
#  '장례',
#  '절차',
#  '반려동물',
#  '분양',
#  '절차',
#  '로드킬',
#  '발견',
#  '시',
#  '신고',
#  '하나요',
#  '과수',
#  '품질',
#  '시설',
#  '대화',
#  '사업',
#  '대해',
#  '과수',
#  '품질',
#  '시설',
#  '대화',
#  '사업',
#  '지원',
#  '자격',
#  '및',
#  '지원',
#  '내용',
#  '신청',
#  '방법',
#  '등',
#  '과수',
#  '분야',
#  '스마트',
#  '확산',
#  '사업',
#  '대해',
#  '유통',
#  '시설',
#  '대화',
#  '사업',
#  '대해',
#  '과실',
#  '브랜드',
#  '사업',
#  '대해',
#  '농지',
#  '보전',
#  '부담',
#  '금은',
#  '무엇',
#  '농지',
#  '보전',
#  '부담',
#  '금',
#  '납부',
#  '관련',
#  '의처',
#  '알',
#  '수',
#  '농지',
#  '보전',
#  '부담',
#  '금',
#  '납입',
#  '확인',
#  '발급',
#  '수',
#  '농지',
#  '법',
#  '농지',
#  '해당',
#  '경우',
#  '생애',
#  '최초',
#  '부동산',
#  '취득',
#  '후',
#  '취득세',
#  '소급',
#  '및',
#  '환급',
#  '대상자',
#  '위택스',
#  '신청',
#  '청탁',
#  '금지',
#  '대해',
#  '청탁',
#  '금지법',
#  '부정',
#  '청탁',
#  '금지',
#  '위반',
#  '사례',
#  '이해충돌',
#  '방지',
#  '세부',
#  '행위',
#  '기준',
#  '대해',
#  '알',
#  '이해충돌',
#  '방지법',
#  '무엇',
#  '청탁',
#  '금지법',
#  '금품',
#  '및',
#  '외부',
#  '강의',
#  '등',
#  '초과',
#  '사례금',
#  '사례',
#  '면제',
#  '확인',
#  '무엇',
#  '어린이',
#  '보호',
#  '포장',
#  '무엇',
#  '수입',
#  '통관',
#  '무엇',
#  '수입',
#  '물품',
#  '가격',
#  '신고',
#  '도란',
#  '무엇',
#  '잠정',
#  '가격',
#  '신고',
#  '도란',
#  '무엇',
#  '다른',
#  '지역',
#  '이사',
#  '경우',
#  '지방세',
#  '자동',
#  '납부',
#  '다시',
#  '신청',
#  '하나요',
#  '농로',
#  '구거',
#  '제방',
#  '등',
#  '개별',
#  '공시지가',
#  '농지',
#  '경우',
#  '농지',
#  '보전',
#  '부담',
#  '금',
#  '부과',
#  '기준',
#  '농지',
#  '보전',
#  '부담',
#  '금',
#  '분할',
#  '납부',
#  '수',
#  '농지',
#  '산림',
#  '임야',
#  '로',
#  '전용',
#  '경우',
#  '농지',
#  '보전',
#  '부담',
#  '금',
#  '수',
#  '농지',
#  '보전',
#  '부담',
#  '금',
#  '납부',
#  '후',
#  '사업',
#  '포기',
#  '경우',
#  '환급',
#  '절차',
#  '행정심판',
#  '청구',
#  '후',
#  '청구',
#  '내용',
#  '수정',
#  '수',
#  '행정심판',
#  '청구',
#  '방법',
#  '청구인',
#  '대리인',
#  '기준',
#  '상세',
#  '알',
#  '처분',
#  '내용',
#  '행정심판',
#  '접수',
#  '대상',
#  '제',
#  '처분',
#  '특별',
#  '행정심판',
#  '위원회',
#  '소관',
#  '중앙',
#  '행정심판',
#  '위원회',
#  '접수',
#  '수',
#  '서면',
#  '행정심판',
#  '접수',
#  '후',
#  '증거',
#  '서류',
#  '추가',
#  '제출',
#  '거나',
#  '주소',
#  '등',
#  '서면',
#  '변경',
#  '수',
#  '행정심판',
#  '청구',
#  '날로',
#  '재결',
#  '기간',
#  '이',
#  '재결',
#  '결과',
#  '행정심판',
#  '재결',
#  '결과',
#  '과정',
#  '중앙',
#  '행정심판',
#  '위원회',
#  '재결',
#  '결과',
#  '이의',
#  '경우',
#  '행정소송',
#  '행정심판',
#  '청구',
#  '때',
#  '국선',
#  '대리인',
#  '선임',
#  '하나요',
#  '행정심판',
#  '청구',
#  '후',
#  '처분',
#  '청',
#  '답변서',
#  '제출',
#  '기간',
#  '심리',
#  '기일',
#  '개최',
#  '일',
#  '재결',
#  '발송',
#  '일자',
#  '등',
#  '알',
#  '공익',
#  '직',
#  '불금',
#  '신청',
#  '하나요',
#  '행정심판',
#  '청구',
#  '작성',
#  '시',
#  '업종',
#  '사건',
#  '유형',
#  '처분',
#  '구분',
#  '및',
#  '사건',
#  '사례',
#  '별',
#  '청구',
#  '조회',
#  '방법',
#  '등',
#  '홈페이지',
#  '볼',
#  '수',
#  '고장',
#  '알리',
#  '서비스',
#  '란',
#  '무엇',
#  '부모',
#  '급여',
#  '란',
#  '무엇',
#  '타인',
#  '명의',
#  '차량',
#  '자동차세',
#  '납',
#  '신청',
#  '수',
#  '환경',
#  '개선',
#  '부담',
#  '금',
#  '납',
#  '신청',
#  '축산물',
#  '등급',
#  '판정',
#  '확인',
#  '를',
#  '온라인',
#  '발급',
#  '수',
#  '위택스',
#  '자동차세',
#  '납',
#  '신청',
#  '하나요',
#  '자동차세',
#  '납',
#  '율',
#  '변경',
#  '지방세',
#  '납부',
#  '시',
#  '가상',
#  '계좌',
#  '이외',
#  '납부',
#  '방법',
#  '위택스',
#  '취득세',
#  '공동',
#  '명의',
#  '건',
#  '대해',
#  '신고',
#  '필증',
#  '일련번호',
#  '관리',
#  '번호',
#  '입력',
#  '시',
#  '오류',
#  '발생',
#  '위택스',
#  '취득세',
#  '신고',
#  '시',
#  '비적정',
#  '메시지',
#  '확인',
#  '신고',
#  '증여',
#  '기부',
#  '등',
#  '무상',
#  '취득',
#  '취득세',
#  '주택',
#  '신고',
#  '전자',
#  '신고',
#  '심폐소생술',
#  '교육',
#  '수',
#  '곳',
#  '어디',
#  '여권',
#  '사실',
#  '증명',
#  '온라인',
#  '발급',
#  '전자소송',
#  '시스템',
#  '통해',
#  '제출',
#  '서류',
#  '종류',
#  '수산',
#  '질병',
#  '관리사',
#  '란',
#  '무엇',
#  '스킨',
#  '스쿠버',
#  '바다',
#  '상황',
#  '미리',
#  '알',
#  '수',
#  '방법',
#  '축산물',
#  '잔류',
#  '물질',
#  '검사',
#  '절차',
#  '알',
#  '동물',
#  '용',
#  '의약품',
#  '사용',
#  '방법',
#  '및',
#  '기준',
#  '무엇',
#  '축산물',
#  '잔류',
#  '물질',
#  '검사',
#  '기관',
#  '어디',
#  '동물',
#  '용',
#  '의약품',
#  '종류',
#  '축산물',
#  '허용',
#  '물질',
#  '목록',
#  '관리제',
#  '무엇',
#  '산지',
#  '연금',
#  '유림',
#  '매수',
#  '제도',
#  '참여',
#  '방법',
#  '알',
#  '신용카드',
#  '해지',
#  '분실',
#  '경우',
#  '위택스',
#  '지방세',
#  '자동',
#  '납부',
#  '신청',
#  '건',
#  '해지',
#  '하나요',
#  '임대',
#  '사업자',
#  '부기',
#  '등기',
#  '등록면허세',
#  '등록',
#  '수필',
#  '확인',
#  '위택스',
#  '임대',
#  '사업자',
#  '부기',
#  '등기',
#  '등록',
#  '신고',
#  '시',
#  '상호',
#  '입력',
#  '하나요',
#  '부기',
#  '등기',
#  '위해',
#  '등록면허세',
#  '등록',
#  '신고',
#  '물건',
#  '여러',
#  '개인',
#  '경우',
#  '번',
#  '신고',
#  '직장',
#  '내',
#  '괴롭힘',
#  '대한',
#  '상담',
#  '소상',
#  '공인',
#  '및',
#  '자영',
#  '업자',
#  '지원',
#  '사업',
#  '것',
#  '생활',
#  '불편',
#  '신고',
#  '앱',
#  '더',
#  '이상',
#  '이용',
#  '수',
#  '스마트폰',
#  '이용',
#  '생활',
#  '속',
#  '불편',
#  '사항',
#  '신고',
#  '방법',
#  '알',
#  '컵',
#  '보증금',
#  '란',
#  '무엇',
#  '건설',
#  '현장',
#  '소방',
#  '안전',
#  '관리자',
#  '선임',
#  '의무',
#  '기준',
#  '택시',
#  '야간',
#  '호출',
#  '제도',
#  '수상',
#  '레저',
#  '기구',
#  '조종',
#  '면허',
#  '갱신',
#  '교육',
#  '수',
#  '출석',
#  '인정',
#  '도란',
#  '무엇',
#  '한국어',
#  '능력',
#  '시험',
#  '한국인',
#  '볼',
#  '수',
#  '한국어',
#  '능력',
#  '시험',
#  '접수',
#  '시',
#  '입력',
#  '응시',
#  '정보',
#  '변경',
#  '수',
#  '한국어',
#  '능력',
#  '시험',
#  '접수',
#  '후',
#  '응시',
#  '료',
#  '결제',
#  '및',
#  '환불',
#  '관련',
#  '한국어',
#  '능력',
#  '시험',
#  '성적',
#  '증명서',
#  '유효',
#  '기간',
#  '얼마나',
#  '한국어',
#  '능력',
#  '시험',
#  '접수',
#  '시',
#  '사진',
#  '등록',
#  '사진',
#  '규격',
#  '어업',
#  '건강검진',
#  '지원',
#  '수',
#  '본인',
#  '부담',
#  '초과',
#  '의료',
#  '비',
#  '환급',
#  '대상',
#  '확인',
#  '중고차',
#  '침수',
#  '사실',
#  '신고',
#  '카페',
#  '일회용품',
#  '사용',
#  '제한',
#  '카페',
#  '건가',
#  '에코',
#  '뱅크',
#  '란',
#  '무엇',
#  '무인',
#  '민원',
#  '발급',
#  '기',
#  '위치',
#  '알',
#  '수',
#  '방법',
#  '어선',
#  '등',
#  '한국',
#  '선박',
#  '근무',
#  '외국인',
#  '선원',
#  '대해',
#  '상담',
#  '수',
#  '곳',
#  '국유재산',
#  '불법',
#  '사용',
#  '것',
#  '신고',
#  '하나요',
#  '국유',
#  '부동산',
#  '소관',
#  '기관',
#  '관리',
#  '기관',
#  '알',
#  '국립종자원',
#  '식물',
#  '대한',
#  '품종',
#  '등록',
#  '출원',
#  '요',
#  '국민',
#  '참여',
#  '플랫폼',
#  '온',
#  '국민',
#  '소통',
#  '이',
#  '무엇',
#  '친환경',
#  '보일러',
#  '보조금',
#  '온라인',
#  '신청',
#  '문화유산',
#  '도서',
#  '무료',
#  '신청',
#  '지방',
#  '소득세',
#  '양도소득',
#  '과세표준',
#  '금액',
#  '입력',
#  '하나요',
#  '지방세',
#  '고지서',
#  '스마트폰',
#  '수',
#  '주민',
#  '등록증',
#  '모바일',
#  '확인',
#  '서비스',
#  '란',
#  '무엇',
#  '형사',
#  '사법',
#  '포털',
#  '인증서',
#  '인증',
#  '제외',
#  '다른',
#  '인증',
#  '이용',
#  '수',
#  '방법',
#  '낫콜',
#  '서비스',
#  '란',
#  '무엇',
#  '주민',
#  '등록증',
#  '신규',
#  '발급',
#  '만',
#  '세',
#  '이상',
#  '최초',
#  '발급',
#  '전국',
#  '어디',
#  '서나',
#  '적극',
#  '행정',
#  '적립',
#  '마일리지',
#  '도란',
#  '무엇',
#  '사업',
#  '휴업',
#  '거나',
#  '폐업',
#  '경우',
#  '사업자',
#  '등록',
#  '하나요',
#  '사업자',
#  '등록',
#  '번호',
#  '부여',
#  '체계',
#  '대해',
#  '사업자',
#  '등록',
#  '과세',
#  '간이',
#  '과세',
#  '차이',
#  '무엇',
#  '사업자',
#  '등록',
#  '다른',
#  '사람',
#  '이름',
#  '불이익',
#  '개인',
#  '사업',
#  '사업자',
#  '등록',
#  '언제',
#  '하나요',
#  '지방',
#  '세입',
#  '계좌',
#  '납부',
#  '서비스',
#  '란',
#  '무엇',
#  '재산세',
#  '분할',
#  '납부',
#  '신청',
#  '시',
#  '지역',
#  '자원',
#  '시설',
#  '세',
#  '지방',
#  '교육세',
#  '모두',
#  '분할',
#  '세액',
#  '납부',
#  '지방세',
#  '자동',
#  '납부',
#  '자치',
#  '단체',
#  '별',
#  '행정',
#  '구별',
#  '로',
#  '신청',
#  '하나요',
#  '양도소득',
#  '신고',
#  '시',
#  '납세',
#  '기준',
#  '인증서',
#  '금융',
#  '인증서',
#  '차이',
#  '뭔가',
#  '아포',
#  '스티',
#  '유',
#  '확인',
#  '콜센터',
#  '란',
#  '가족',
#  '관계',
#  '증명서',
#  '전자문서',
#  '지갑',
#  '수',
#  '계란',
#  '생산',
#  '유통',
#  '이력',
#  '확인',
#  '하나요',
#  '동물',
#  '사랑',
#  '배움터',
#  '무얼',
#  '곳',
#  '임대차',
#  '계약',
#  '시',
#  '정식',
#  '계약서',
#  '약식',
#  '계약서',
#  '사용',
#  '신고',
#  '수',
#  '자가용',
#  '화물차',
#  '이용',
#  '불법',
#  '화물',
#  '운송',
#  '차량',
#  '신고',
#  '식당',
#  '해외',
#  '산',
#  '수산물',
#  '국산',
#  '수산물',
#  '판매',
#  '신고',
#  '수산물',
#  '원산지',
#  '표시',
#  '대해',
#  '해파리',
#  '신고',
#  '군',
#  '생활',
#  '어려움',
#  '고충',
#  '민원',
#  '접수',
#  '국민',
#  '제안',
#  '홈페이지',
#  '청원',
#  '국회',
#  '진행',
#  '국민',
#  '동의',
#  '청원',
#  '가요',
#  '정신질환',
#  '자가',
#  '검진',
#  '사이트',
#  '광역',
#  '정신건강',
#  '복지',
#  '센터',
#  '기초',
#  '정신건강',
#  '복지',
#  '센터',
#  '무엇',
#  '가요',
#  '해외',
#  '거주',
#  '병역',
#  '증명서',
#  '발급',
#  '수',
#  '바다',
#  '내비게이션',
#  '무엇',
#  '금',
#  '어기',
#  '금지',
#  '체',
#  '무엇',
#  '사물',
#  '주소',
#  '등록',
#  '하나요',
#  '해',
#  '로드',
#  '란',
#  '무엇',
#  '농지',
#  '부가',
#  '농지',
#  '대장',
#  '개편',
#  '무엇',
#  '것',
#  '탄소',
#  '포인트',
#  '제',
#  '무엇',
#  '항로',
#  '표지',
#  ...]

# %%
import re

# %%
tokens =[re.sub('[^가-힣]', '', token) for token in tokens]

# %%
len(tokens)
# Out:
# 2724

# %% [markdown]
# # 최빈단어 추출

# %%
semi = nltk.Text(tokens, name='정부민원 최빈 단어')

# Generate the plot
plt.figure(figsize=(15,6))
semi.plot(50)

# Display the plot
plt.show()

# %%
stop_words = stoptext.split()
tokens = [token for token in tokens if token not in stop_words]

# %%
# 제거해야하는 단어 입력후 실행
# stop_words 쪽으로 가서 한번더 실행하고 그래프 실행시키면 적용됨
stoptext = '''
무엇 수 하나요 방법 시 확인 경우 알 및 어디 란 후 등 곳 것 
'''

# %% [markdown]
# # 워드 클라우드

# %%
# 데이터 불러오기 
data = semi.vocab().most_common(300)
font_path = r'C:\Windows\Fonts\malgun.ttf'

# %%
# Wordcloud 를 wc 로 지정 및 시각화 설정
wc = WordCloud(background_color='white',
               font_path = font_path,
               relative_scaling=0.2).generate_from_frequencies(dict(data))

# %%
# 시각화 
plt.figure(figsize = (10,6))
plt.imshow(wc,interpolation='bilinear')
plt.axis('off')
plt.show()
