# %%
filename = './API/kakaoAPI.txt'
with open(filename) as f:
    api_key = f.read()

# %%
len(api_key2)
# Out:
# 66

# %%
import requests
from urllib.parse import quote
import json

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import folium
from shapely.geometry import Polygon
# %matplotlib inline
import matplotlib.font_manager
import re

# 폰트 설정
mpl.rc('font', family='NanumGothic')
# 유니코드에서  음수 부호설정
mpl.rc('axes', unicode_minus=False)

# %%
df = pd.read_csv('./datos_project/12_21_schoolzone.csv', encoding='cp949')

# %%
df.head()
# Out:
#    사고다발지FID  사고다발지ID       법정동코드      지점코드      시도시군구명  \
# 0     99210  2013060  1111016900  11110001  서울특별시 종로구1
# 1     99846  2013060  1129013500  11290001  서울특별시 성북구1
# 2     98904  2013060  1129011000  11290002  서울특별시 성북구2
# 3     99206  2013060  1129013900  11290003  서울특별시 성북구3
# 4     99209  2013060  1132010500  11320001  서울특별시 도봉구1
#
#                          지점명  발생건수  사상자수  사망자수  중상자수  경상자수  부상신고자수  \
# 0     서울특별시 종로구 혜화동(혜화초교 부근)     2     2     0     1     1       0
# 1     서울특별시 성북구 종암동(숭례초교 부근)     2     2     0     0     1       1
# 2  서울특별시 성북구 동소문동7가(정덕초교 부근)     2     2     0     2     0       0
# 3     서울특별시 성북구 석관동(석관초교 부근)     3     3     0     2     1       0
# 4     서울특별시 도봉구 쌍문동(쌍문초교 부근)     2     2     0     0     2       0
#
#            경도         위도                                            다발지역폴리곤
# 0  126.999607  37.588413  {"type":"Polygon","coordinates":[[[127.002009,...
# 1  127.035733  37.595505  {"type":"Polygon","coordinates":[[[127.0381354...
# 2  127.014564  37.597571  {"type":"Polygon","coordinates":[[[127.0169658...
# 3  127.059596  37.610429  {"type":"Polygon","coordinates":[[[127.0619982...
# 4  127.024430  37.648129  {"type":"Polygon","coordinates":[[[127.0268336...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 391 entries, 0 to 390
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   사고다발지FID  391 non-null    int64
#  1   사고다발지ID   391 non-null    int64
#  2   법정동코드     391 non-null    int64
#  3   지점코드      391 non-null    int64
#  4   시도시군구명    391 non-null    object
#  5   지점명       391 non-null    object
#  6   발생건수      391 non-null    int64
#  7   사상자수      391 non-null    int64
#  8   사망자수      391 non-null    int64
#  9   중상자수      391 non-null    int64
#  10  경상자수      391 non-null    int64
#  11  부상신고자수    391 non-null    int64
#  12  경도        391 non-null    float64
#  13  위도        391 non-null    float64
#  14  다발지역폴리곤   391 non-null    object
# dtypes: float64(2), int64(10), object(3)
# memory usage: 45.9+ KB

# %%
# 시도시군구명, 지점명, 발생건수, 사상자수, 사망자수, 중상자수, 경상자수, 부상신고자수, 경도, 위도 컬럼만 선택
df1 = df[['시도시군구명', '지점명', '발생건수', '사상자수', '사망자수', '중상자수', '경상자수', '부상신고자수', '경도', '위도']]

# %%
df1.tail()
# Out:
#               시도시군구명                          지점명  발생건수  사상자수  사망자수  중상자수  \
# 386        경상북도 영천시1        경상북도 영천시 망정동(포은초교 부근)     2     2     0     1
# 387        경상북도 경산시1      경상북도 경산시 계양동(경산동부초교 부근)     3     3     0     1
# 388        경상북도 군위군1        경상북도 군위군 군위읍(군위초교 부근)     2     2     0     0
# 389        경상북도 예천군1        경상북도 예천군 호명면(호명초교 부근)     2     2     0     0
# 390  경상남도 창원시 마산합포구1  경상남도 창원시 마산합포구 교방동(교방초교 부근)     2     2     0     0
#
#      경상자수  부상신고자수          경도         위도
# 386     1       0  128.951457  35.980469
# 387     2       0  128.749990  35.818530
# 388     1       1  128.567712  36.238855
# 389     2       0  128.480525  36.578257
# 390     2       0  128.565034  35.214236

# %%
# 서울특별시 행들만 선택
df2 = df1[df1['시도시군구명'].str.contains('서울특별시')]
df2.tail()
# Out:
#           시도시군구명                          지점명  발생건수  사상자수  사망자수  중상자수  경상자수  \
# 354   서울특별시 강서구1     서울특별시 강서구 마곡동(서울공진초교 부근)     2     2     0     0     2
# 355   서울특별시 구로구1     서울특별시 구로구 구로동(샛별어린이집 부근)     2     2     0     0     2
# 356  서울특별시 영등포구1  서울특별시 영등포구 양평동3가(서울선유초교 부근)     2     2     0     0     2
# 357  서울특별시 영등포구2    서울특별시 영등포구 신길동(서울도림초교 부근)     1     1     1     0     0
# 358   서울특별시 관악구1     서울특별시 관악구 신림동(서울난우초교 부근)     2     2     0     1     1
#
#      부상신고자수          경도         위도
# 354       0  126.823915  37.558399
# 355       0  126.884800  37.499774
# 356       0  126.892676  37.531723
# 357       0  126.907025  37.506284
# 358       0  126.918652  37.476159

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70 entries, 0 to 358
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시도시군구명  70 non-null     object
#  1   지점명     70 non-null     object
#  2   발생건수    70 non-null     int64
#  3   사상자수    70 non-null     int64
#  4   사망자수    70 non-null     int64
#  5   중상자수    70 non-null     int64
#  6   경상자수    70 non-null     int64
#  7   부상신고자수  70 non-null     int64
#  8   경도      70 non-null     float64
#  9   위도      70 non-null     float64
# dtypes: float64(2), int64(6), object(2)
# memory usage: 6.0+ KB

# %%
#시도, 시군구 커러럼 분할
df2[['시도', '시군구']] = df2['시도시군구명'].str.split(' ', n=1, expand=True)
df2.head()
# Out:
# C:\Users\Kipioneer\AppData\Local\Temp\ipykernel_13744\2747408451.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[['시도', '시군구']] = df2['시도시군구명'].str.split(' ', n=1, expand=True)
# C:\Users\Kipioneer\AppData\Local\Temp\ipykernel_13744\2747408451.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[['시도', '시군구']] = df2['시도시군구명'].str.split(' ', n=1, expand=True)
#        시도시군구명                        지점명  발생건수  사상자수  사망자수  중상자수  경상자수  \
# 0  서울특별시 종로구1     서울특별시 종로구 혜화동(혜화초교 부근)     2     2     0     1     1
# 1  서울특별시 성북구1     서울특별시 성북구 종암동(숭례초교 부근)     2     2     0     0     1
# 2  서울특별시 성북구2  서울특별시 성북구 동소문동7가(정덕초교 부근)     2     2     0     2     0
# 3  서울특별시 성북구3     서울특별시 성북구 석관동(석관초교 부근)     3     3     0     2     1
# 4  서울특별시 도봉구1     서울특별시 도봉구 쌍문동(쌍문초교 부근)     2     2     0     0     2
#
#    부상신고자수          경도         위도     시도   시군구
# 0       0  126.999607  37.588413  서울특별시  종로구1
# 1       1  127.035733  37.595505  서울특별시  성북구1
# 2       0  127.014564  37.597571  서울특별시  성북구2
# 3       0  127.059596  37.610429  서울특별시  성북구3
# 4       0  127.024430  37.648129  서울특별시  도봉구1

# %%
df2 = df2.drop('시도시군구명', axis=1)
df2
# Out:
#                              지점명  발생건수  사상자수  사망자수  중상자수  경상자수  부상신고자수  \
# 0         서울특별시 종로구 혜화동(혜화초교 부근)     2     2     0     1     1       0
# 1         서울특별시 성북구 종암동(숭례초교 부근)     2     2     0     0     1       1
# 2      서울특별시 성북구 동소문동7가(정덕초교 부근)     2     2     0     2     0       0
# 3         서울특별시 성북구 석관동(석관초교 부근)     3     3     0     2     1       0
# 4         서울특별시 도봉구 쌍문동(쌍문초교 부근)     2     2     0     0     2       0
# ..                           ...   ...   ...   ...   ...   ...     ...
# 354     서울특별시 강서구 마곡동(서울공진초교 부근)     2     2     0     0     2       0
# 355     서울특별시 구로구 구로동(샛별어린이집 부근)     2     2     0     0     2       0
# 356  서울특별시 영등포구 양평동3가(서울선유초교 부근)     2     2     0     0     2       0
# 357    서울특별시 영등포구 신길동(서울도림초교 부근)     1     1     1     0     0       0
# 358     서울특별시 관악구 신림동(서울난우초교 부근)     2     2     0     1     1       0
#
#              경도         위도     시도    시군구
# 0    126.999607  37.588413  서울특별시   종로구1
# 1    127.035733  37.595505  서울특별시   성북구1
# 2    127.014564  37.597571  서울특별시   성북구2
# 3    127.059596  37.610429  서울특별시   성북구3
# 4    127.024430  37.648129  서울특별시   도봉구1
# ..          ...        ...    ...    ...
# 354  126.823915  37.558399  서울특별시   강서구1
# 355  126.884800  37.499774  서울특별시   구로구1
# 356  126.892676  37.531723  서울특별시  영등포구1
# 357  126.907025  37.506284  서울특별시  영등포구2
# 358  126.918652  37.476159  서울특별시   관악구1
#
# [70 rows x 11 columns]

# %%
df2  = df2[['시도', '시군구', '지점명', '발생건수', '사상자수', '사망자수', '중상자수', '경상자수', '부상신고자수', '경도', '위도']]
df2.head()
# Out:
#       시도   시군구                        지점명  발생건수  사상자수  사망자수  중상자수  경상자수  \
# 0  서울특별시  종로구1     서울특별시 종로구 혜화동(혜화초교 부근)     2     2     0     1     1
# 1  서울특별시  성북구1     서울특별시 성북구 종암동(숭례초교 부근)     2     2     0     0     1
# 2  서울특별시  성북구2  서울특별시 성북구 동소문동7가(정덕초교 부근)     2     2     0     2     0
# 3  서울특별시  성북구3     서울특별시 성북구 석관동(석관초교 부근)     3     3     0     2     1
# 4  서울특별시  도봉구1     서울특별시 도봉구 쌍문동(쌍문초교 부근)     2     2     0     0     2
#
#    부상신고자수          경도         위도
# 0       0  126.999607  37.588413
# 1       1  127.035733  37.595505
# 2       0  127.014564  37.597571
# 3       0  127.059596  37.610429
# 4       0  127.024430  37.648129

# %%
# 시군구 숫자제거
df2['시군구'] = df2['시군구'].apply(lambda x: re.sub(r'\d+', '', x))
df2.head(3)
# Out:
#       시도  시군구                        지점명  발생건수  사상자수  사망자수  중상자수  경상자수  \
# 0  서울특별시  종로구     서울특별시 종로구 혜화동(혜화초교 부근)     2     2     0     1     1
# 1  서울특별시  성북구     서울특별시 성북구 종암동(숭례초교 부근)     2     2     0     0     1
# 2  서울특별시  성북구  서울특별시 성북구 동소문동7가(정덕초교 부근)     2     2     0     2     0
#
#    부상신고자수          경도         위도
# 0       0  126.999607  37.588413
# 1       1  127.035733  37.595505
# 2       0  127.014564  37.597571

# %%
# 구별로 그룹화
df3 = df2.groupby('시군구')['발생건수', '사상자수', '사망자수', '중상자수', '경상자수', '부상신고자수'].agg('sum')
df3.head(3)
# Out:
# C:\Users\Kipioneer\AppData\Local\Temp\ipykernel_13744\3039969391.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df3 = df2.groupby('시군구')['발생건수', '사상자수', '사망자수', '중상자수', '경상자수', '부상신고자수'].agg('sum')
#      발생건수  사상자수  사망자수  중상자수  경상자수  부상신고자수
# 시군구
# 강남구     6     6     0     2     4       0
# 강동구     3     3     1     1     1       0
# 강북구     5     5     0     1     4       0

# %%
# 발생건수만 사용
df4 = df3.groupby('시군구')['발생건수'].sum()

# %%
#구별 스쿨존 내 어린이 사고 발생건수
df3.plot.bar()
# Out:
# <Axes: xlabel='시군구'>

# %%
#구별 스쿨존 내 어린이 사고 발생건수 내림차순
df4.sort_values(ascending=False).plot.bar()
# Out:
# <Axes: xlabel='시군구'>

# %%
# CCTV 개수가 가장 적은 구로구 어린이 스쿨존 내 교통사고
# 발생건수,사상자수, 사망자수, 중상자수, 경상자수, 부상신고자수

guro_pie = df3.loc['구로구',['사망자수', '중상자수', '경상자수', '부상신고자수']]

#파이차트

plt.pie(guro_pie, labels=guro_pie.index, autopct='%1.1f%%', startangle=90)
plt.title('구로구 스쿨존내 어린이 사고현황')
plt.show()

# %%
# CCTV 개수가 가장 적은 송파구 어린이 스쿨존 내 교통사고
# 발생건수,사상자수, 사망자수, 중상자수, 경상자수, 부상신고자수

guro_pie = df3.loc['송파구',['사망자수', '중상자수', '경상자수', '부상신고자수']]

#파이차트

plt.pie(guro_pie, labels=guro_pie.index, autopct='%1.1f%%', startangle=90)
plt.title('송파구 스쿨존내 어린이 사고현황')
plt.show()

# %%
df3
# Out:
#       발생건수  사상자수  사망자수  중상자수  경상자수  부상신고자수
# 시군구
# 강남구      6     6     0     2     4       0
# 강동구      3     3     1     1     1       0
# 강북구      5     5     0     1     4       0
# 강서구     12    12     1     2     7       2
# 관악구      4     4     2     1     1       0
# 광진구      2     2     0     0     2       0
# 구로구     23    26     0     8    13       5
# 금천구      1     1     1     0     0       0
# 노원구      7    13     2     5     5       1
# 도봉구      7     7     0     3     4       0
# 동대문구     4     4     0     3     1       0
# 동작구     10    10     1     3     5       1
# 서대문구     2     2     0     1     1       0
# 서초구      2     2     0     2     0       0
# 성북구     18    18     0     6    11       1
# 송파구      2     2     0     0     2       0
# 양천구      4     5     1     0     4       0
# 영등포구     3     3     1     0     2       0
# 은평구     15    15     0     5     7       3
# 종로구      6     6     0     1     3       2
# 중랑구      7     7     0     1     6       0

# %%
center = [37.5502, 126.982]

# folium
map = folium.Map(location=center, zoom_start=11)

# 각 데이터 포인트마다 지도에 마커를 추가합니다
for idx, row in df2.iterrows():
    lon, lat = row['경도'], row['위도']
    # 마커
    marker = folium.Marker(location=[lat, lon])
    # 맵에 마커를 추가
    marker.add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7d3015f2e95e29e3d908ebadd3d71936 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7d3015f2e95e29e3d908ebadd3d71936&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7d3015f2e95e29e3d908ebadd3d71936 = L.map(
#                 &quot;map_7d3015f2e95e29e3d908ebadd3d71936&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_88f76c106b5ed65600a4ef209b354bd0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_bcddb77a4db2db06f40f044621e27b0e = L.marker(
#                 [37.588412912227, 126.999607102287],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_a5efaa901f5ec157585b49d53ba9cf0c = L.marker(
#                 [37.595504719468, 127.035733238499],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_2c21ce10e5c49182a1272723b07becf7 = L.marker(
#                 [37.597571435274, 127.014563577948],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_434be384ad7ab3209ced859a2dd0bb1b = L.marker(
#                 [37.610428918461, 127.059595620343],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_43d1a3c04605334c71a90dc1f0e8178f = L.marker(
#                 [37.648128924012, 127.024429760426],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_377974c9fc60993fa86e9fc1974b56ac = L.marker(
#                 [37.66443683879, 127.056828023296],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_3c4f12a5657d847fbd5632f9b97c5cae = L.marker(
#                 [37.489939519694, 126.856930104842],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_d08d936cf0f72c4c5ffbc6ff39bd9b54 = L.marker(
#                 [37.503920591563, 126.845830640673],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_cb5b0c172fb4a12d426f062984a7df18 = L.marker(
#                 [37.509796540579, 127.122101032338],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_d5299f71e4abf04817c7e8a234e39bc6 = L.marker(
#                 [37.56646131364, 127.071575225817],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_e685807c5dc365f42d241172d710f54c = L.marker(
#                 [37.589352820677, 126.945490820846],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_109189d4e2353db55df641f67eea3744 = L.marker(
#                 [37.499924920799, 126.889516531963],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_16bcc22ef3c8f755388075f0593a2e4b = L.marker(
#                 [37.484039729651, 126.890618550407],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_5484e6ba90fcc05a260563fffa00964b = L.marker(
#                 [37.503732944421, 126.960785734775],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_6e1d03a18646318c210f8f635b8f4395 = L.marker(
#                 [37.574149339921, 127.073931999963],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_b6071fde8b2e63e218a41c237674b6b0 = L.marker(
#                 [37.643088860663, 127.039227311492],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_af271cd04e8e7c4b0272a540e588127a = L.marker(
#                 [37.674562272432, 127.06015889272],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_fb5a9b3bf143a21fd78eae902f0fa8b1 = L.marker(
#                 [37.620047718129, 126.916365772763],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_32874716344799e37fde3483725b719a = L.marker(
#                 [37.609477501387, 126.915043475277],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_dcebb9e9ed779c9f36d35

# %%
# 스쿨존내 어린이 사고 다발지역 위치를  Marker로 표시
for name, lat, lng in zip(df2.지점명, df2.위도, df2.경도):
    folium.Marker([lat, lng], popup=name).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7d3015f2e95e29e3d908ebadd3d71936 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7d3015f2e95e29e3d908ebadd3d71936&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7d3015f2e95e29e3d908ebadd3d71936 = L.map(
#                 &quot;map_7d3015f2e95e29e3d908ebadd3d71936&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_88f76c106b5ed65600a4ef209b354bd0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_bcddb77a4db2db06f40f044621e27b0e = L.marker(
#                 [37.588412912227, 126.999607102287],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_a5efaa901f5ec157585b49d53ba9cf0c = L.marker(
#                 [37.595504719468, 127.035733238499],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_2c21ce10e5c49182a1272723b07becf7 = L.marker(
#                 [37.597571435274, 127.014563577948],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_434be384ad7ab3209ced859a2dd0bb1b = L.marker(
#                 [37.610428918461, 127.059595620343],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_43d1a3c04605334c71a90dc1f0e8178f = L.marker(
#                 [37.648128924012, 127.024429760426],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_377974c9fc60993fa86e9fc1974b56ac = L.marker(
#                 [37.66443683879, 127.056828023296],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_3c4f12a5657d847fbd5632f9b97c5cae = L.marker(
#                 [37.489939519694, 126.856930104842],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_d08d936cf0f72c4c5ffbc6ff39bd9b54 = L.marker(
#                 [37.503920591563, 126.845830640673],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_cb5b0c172fb4a12d426f062984a7df18 = L.marker(
#                 [37.509796540579, 127.122101032338],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_d5299f71e4abf04817c7e8a234e39bc6 = L.marker(
#                 [37.56646131364, 127.071575225817],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_e685807c5dc365f42d241172d710f54c = L.marker(
#                 [37.589352820677, 126.945490820846],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_109189d4e2353db55df641f67eea3744 = L.marker(
#                 [37.499924920799, 126.889516531963],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_16bcc22ef3c8f755388075f0593a2e4b = L.marker(
#                 [37.484039729651, 126.890618550407],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_5484e6ba90fcc05a260563fffa00964b = L.marker(
#                 [37.503732944421, 126.960785734775],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_6e1d03a18646318c210f8f635b8f4395 = L.marker(
#                 [37.574149339921, 127.073931999963],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_b6071fde8b2e63e218a41c237674b6b0 = L.marker(
#                 [37.643088860663, 127.039227311492],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_af271cd04e8e7c4b0272a540e588127a = L.marker(
#                 [37.674562272432, 127.06015889272],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_fb5a9b3bf143a21fd78eae902f0fa8b1 = L.marker(
#                 [37.620047718129, 126.916365772763],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_32874716344799e37fde3483725b719a = L.marker(
#                 [37.609477501387, 126.915043475277],
#                 {}
#             ).addTo(map_7d3015f2e95e29e3d908ebadd3d71936);
#
#
#             var marker_dcebb9e9ed779c9f36d35
